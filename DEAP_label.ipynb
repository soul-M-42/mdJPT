# %%
import scipy
label_mat = scipy.io.loadmat('/mnt/dataset0/**/EEG_raw/DEAP/metadata_csv/labels_reorder_lsz_data_medianBin.mat')

# %%
label = label_mat['labels_reorder_lsz_data_medianBin']

# %%
label[0][0][0][0][7][0].shape
# Out:
# (40,)

# %%
import numpy as np
label_final = np.zeros((32, 40))
for sub in range(32):
    print(label[0][0][0][0][sub][0].shape)
    for vid in range(40):
        try:
            label_final[sub][vid] = label[0][0][0][0][sub][0][vid]
        except:
            pass
# Out:
# (40,)
# (40,)
# (40,)
# (40,)
# (40,)
# (40,)
# (40,)
# (40,)
# (40,)
# (39,)
# (40,)
# (40,)
# (40,)
# (40,)
# (38,)
# (40,)
# (40,)
# (38,)
# (40,)
# (40,)
# (40,)
# (39,)
# (40,)
# (40,)
# (40,)
# (40,)
# (39,)
# (40,)
# (40,)
# (39,)
# (40,)
# (40,)

# %%
import matplotlib.pyplot as plt
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
show_data(label_final)
