# %%
data_dir_me = '/mnt/dataset0/**/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/patch_multi_f0_fea_epoch=19.ckptme.npy'
data_dir_de = '/mnt/dataset0/**/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/patch_multi_f0_fea_epoch=19.ckptde.npy'

# %%
import numpy as np
data_de = np.load(data_dir_de)
data_me = np.load(data_dir_me)

# %%
import numpy as np
data = np.load(data_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import numpy as np
# ----> 2 data = np.load(data_dir)
#
# NameError: name 'data_dir' is not defined

# %%
data.shape
# Out:
# (57616, 256)

# %%
import matplotlib.pyplot as plt

# %%
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()

# %%
show_data(data[:512])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 show_data(data[:512])
#
# NameError: name 'data' is not defined

# %%
import numpy as np
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = '/mnt/dataset0/**/workspace/Covariance_EEG_Emotion/visualize/features/SEEDV_DE/DE_NOLDS_NONORM.npy'
data = np.load(data_dir)
print(data.shape)
show_data(data[:512])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 data_dir = '/mnt/dataset0/**/workspace/Covariance_EEG_Emotion/visualize/features/SEEDV_DE/DE_NOLDS_NONORM.npy'
# ----> 2 data = np.load(data_dir)
#       3 print(data.shape)
#       4 show_data(data[:512])
#
# NameError: name 'np' is not defined

# %%
dir_old = '/mnt/dataset0/**/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/CNN_baseline_f0_fea_pretrain_me.npy'
data_old = np.load(dir_old)
print(data_old.shape)
show_data(data_old[:512])
# Out:
# (117744, 256)

# %%
dir_cnn_new = '/mnt/dataset0/**/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/CNN_bsl_f0_fea_epoch=19.ckptde.npy'
data_cnn_new = np.load(dir_cnn_new)
print(data_cnn_new.shape)
show_data(data_cnn_new[:512])
# Out:
# (117744, 256)

# %%
dir_mlla = '/mnt/dataset0/**/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/replace_align_f0_fea_DE.npy'
data_mlla = np.load(dir_mlla)
print(data_mlla.shape)
show_data(data_mlla[:512])
# Out:
# (117744, 300)

# %%
dir_determin = '/mnt/dataset0/**/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/cnnNormAfterMLP_f0_fea_epoch=19.ckptme.npy'
data_determin = np.load(dir_determin)
print(data_determin.shape)
show_data(data_determin[:512])
# Out:
# (57616, 256)

# %%
dir_determin = '/mnt/dataset0/**/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/cnnNormAfterMLP_f0_fea_DE.npy'
data_determin = np.load(dir_determin)
print(data_determin.shape)
show_data(data_determin[:512])
# Out:
# (57616, 300)

# %%
import torch

# 创建随机 Tensor
tensor = torch.randn(30, 1, 60, 625, dtype=torch.float32, device="cuda")

# 查看内存占用
print(f"Tensor 内存占用: {tensor.element_size() * tensor.numel() / 1024**2:.2f} MB")
# Out:
# Tensor 内存占用: 4.29 MB

# %%
import numpy as np
import matplotlib.pyplot as plt 
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = './saved_data/beforeTSTencoder.npy'
data_show = np.load(data_dir)
print(data_show.shape)
show_data(data_show[8])
# Out:
# (64, 60, 625)

# %%
import numpy as np
import matplotlib.pyplot as plt 
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = './saved_data/afterTSTencoder.npy'
data_show = np.load(data_dir)
print(data_show.shape)
show_data(data_show.reshape((64, 60 * 16, 149))[8])
# Out:
# (64, 60, 16, 149)

# %%
import numpy as np
import matplotlib.pyplot as plt 
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = './saved_data/afterTFencoder.npy'
data_show = np.load(data_dir)
print(data_show.shape)
show_data(data_show[8])
# Out:
# (64, 60, 149, 32)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 11
#       9 data_show = np.load(data_dir)
#      10 print(data_show.shape)
# ---> 11 show_data(data_show[8])
#
# Cell In[59], line 5, in show_data(data)
#       3 def show_data(data):
#       4     fig, ax = plt.subplots()
# ----> 5     cax = ax.imshow(data)
#       6     fig.colorbar(cax)
#       7     plt.show()
#
# File ~/miniconda3/envs/torch/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
# ...

# %%
show_data(data_show[8])

# %%
import numpy as np
data = np.load('./visualize/projected_eeg.npy')
data.shape
# Out:
# (30, 1, 94, 625)

# %%
data_trial = data[0][0]

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_multichannel_data(data, x=None, offset=None, spacing=3.0, 
                          channel_labels=None, cmap='viridis', ax=None, **kwargs):
    """
    绘制多通道时间序列数据，自动垂直偏移通道
    
    参数：
    data : ndarray, shape (n_channels, n_time)
        输入的多通道时间序列数据
    x : ndarray, shape (n_time,), optional
        时间轴数据，默认为 [0, 1, ..., n_time-1]
    offset : float, optional
        通道间垂直偏移量，自动计算时使用 spacing * max_amplitude
    spacing : float
        通道间距系数（当offset为None时生效）
    channel_labels : list of str, optional
        通道标签列表
    cmap : str
        颜色映射名称
    ax : matplotlib axis, optional
        指定绘图的axis对象
    **kwargs : 
        传递给plot函数的其他参数
    """
    # 验证输入数据维度
    if data.ndim != 2:
        raise ValueError("输入数据必须是二维数组 (n_channels, n_time)")
    
    n_channels, n_time = data.shape
    x = np.arange(n_time) if x is None else x
    
    # 自动计算垂直偏移量
    if offset is None:
        max_amp = np.max(np.abs(data))
        offset = max_amp * spacing
    
    # 创建颜色映射
    colors = plt.cm.get_cmap(cmap)(np.linspace(0, 1, n_channels))
    
    # 创建或获取axis对象
    ax = ax if ax is not None else plt.gca()
    
    # 绘制每个通道
    for i in range(n_channels):
        y_shifted = data[i] + i * offset
        ax.plot(x, y_shifted, color='#B95767', **kwargs)
    
    # 设置y轴标签
    yticks = [i * offset for i in range(n_channels)]
    yticklabels = channel_labels if channel_labels else [f'Channel {i}' for i in range(n_channels)]
    ax.set_yticks(yticks)
    ax.set_yticklabels(yticklabels)
    
    ax.set_xlabel('Time')
    return ax

# plt.figure(figsize=(10, 6))
# plot_multichannel_data(data_trial, spacing=0)
# plt.title('Multichannel Biosignal Visualization')
# plt.tight_layout()
# plt.show()

# %%
import numpy as np
data = np.load('./visualize/data_before_project.npy')
data_show = data[0][0]
print(data_show.shape)
plt.figure(figsize=(5, 3))
plot_multichannel_data(data_show[-4:, :300], spacing=1.4)
plt.title('Multichannel Biosignal Visualization')
plt.tight_layout()
plt.show()
# Out:
# (60, 625)
# /tmp/ipykernel_1114363/891570697.py:40: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap(cmap)(np.linspace(0, 1, n_channels))

# %%
import numpy as np
data = np.load('./visualize/projected_eeg.npy')
data_show = data[0][0]
print(data_show.shape)
plt.figure(figsize=(10, 6))
plot_multichannel_data(data_show, spacing=0.4)
plt.title('Multichannel Biosignal Visualization')
plt.tight_layout()
plt.show()
# Out:
# (94, 625)
# /tmp/ipykernel_3705135/888038347.py:40: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap(cmap)(np.linspace(0, 1, n_channels))

# %%
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
pro_mat = np.load('./visualize/project_matrix.npy')
show_data(pro_mat)

# %%
# Out:
# (94, 61452)

# %%
import numpy as np
cha_weight_dir = '/mnt/dataset1/ws2319/workspace/ESI_pipelines/**/leadfield_fsaverage_standard_1020.npz'
leadfield = np.load(cha_weight_dir)['leadfield']

# %%
show_data(leadfield @ np.linalg.pinv(leadfield))

# %%
L = leadfield
print(L.shape)
C = np.eye(L.shape[0])
W = np.linalg.inv(L.T @ np.linalg.inv(C) @ L) @ L.T @ np.linalg.inv(C)
print(W.shape)
# Out:
# (94, 61452)
# (61452, 94)

# %%
import matplotlib.pyplot as plt
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
pro_mat = np.load('./visualize/project_matrix.npy')
show_data(L @ W)

# %%
L = leadfield.T
print(L.shape)
C = np.eye(L.shape[0])
W = np.linalg.inv(L.T @ np.linalg.inv(C) @ L) @ L.T @ np.linalg.inv(C)
print(W.shape)
# Out:
# (61452, 94)
# (94, 61452)

# %%
import matplotlib.pyplot as plt
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
show_data(W @ L)

# %%
import numpy as np
cha_weight_dir = '/mnt/dataset1/ws2319/workspace/ESI_pipelines/**/leadfield_fsaverage_standard_1020.npz'
cha_weight_dir = '/mnt/dataset1/ws2319/workspace/ESI_pipelines/**/leadfield_fsaverage_biosemi32.npz'
leadfield = np.load(cha_weight_dir)['leadfield']
show_data(leadfield @ np.linalg.pinv(leadfield))

# %%
L = leadfield.T
print(L.shape)
C = np.eye(L.shape[0])
W = np.linalg.inv(L.T @ np.linalg.inv(C) @ L) @ L.T @ np.linalg.inv(C)
print(W.shape)
show_data(W @ L)
# Out:
# (61452, 32)

# %%
import numpy as np
cha_weight_dir = '/mnt/dataset1/ws2319/workspace/ESI_pipelines/**/leadfield_fsaverage_standard_1020.npz'
leadfield = np.load(cha_weight_dir)['leadfield']
L = leadfield
print(L.shape)
C = np.eye(L.shape[0])
W = np.linalg.inv(L.T @ np.linalg.inv(C) @ L) @ L.T @ np.linalg.inv(C)
print(W.shape)
# Out:
# (94, 61452)
# (61452, 94)

# %%
uni_channel_names = np.load(cha_weight_dir)['uni']
standard_channels_upper = [name.upper() for name in uni_channel_names]
cha_source_upper = [name.upper() for name in cha_source]

# 筛选有效通道
valid_indices = []
valid_source_indices = []
for idx, name in enumerate(cha_source_upper):
    if name in standard_channels_upper:
        valid_indices.append(standard_channels_upper.index(name))
        valid_source_indices.append(idx)
if not valid_indices:
    raise ValueError("没有有效的通道可以映射")

# 验证数据维度
batch_size, _, n_channel_source, n_time = data.shape
assert n_channel_source == len(cha_source), "输入通道数不匹配"

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Arial'

# 示例数据
datasets = [ 'F','S7','S3', 'S3+S7','S3+F', 'S3+S7+F', 'S3+S7+F+D', 'S3+S4+S7+F+D']

acc_dict = {
    'S7':55.46,
    'F':48.90,
    'S3':56.47,
    'S3+S7':59.46,
    'F+D':0.0,
    'S3+F':59.71,
    'S3+S7+F':62.25,
    'S3+F+D':61.93,
    'S3+S4+S7+D':64.16,
    'S3+S7+F+D':64.83,
    'S3+S4+S7+F+D':65.02,
}
std_dict = {
    'S7':2.49,
    'F':1.91,
    'S3':1.65,
    'S3+S7':1.24,
    'F+D':0.0,
    'S3+F':1.90,
    'S3+S7+F':1.22,
    'S3+F+D':1.75,
    'S3+S4+S7+D':1.70,
    'S3+S7+F+D':1.52,
    'S3+S4+S7+F+D':1.32
}
acc = [acc_dict[dataset_i] for dataset_i in datasets]
std = [std_dict[dataset_i] for dataset_i in datasets]
# 创建横向柱状图
plt.figure(figsize=(8, 5))  # 设置图形大小
# bars = plt.barh(datasets, acc, xerr=std, 
#                 color='skyblue',
#                 ecolor='skyblue',
#                 capsize=5,
#                 ecolor
#                 )  # 横向柱状图

bars = plt.barh(datasets, acc, color='tab:blue')

# 添加误差条
for i, (bar, err) in enumerate(zip(bars, std)):
    x = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2

    # 使用 errorbar 单独画误差条
    plt.errorbar(
        x, y,
        xerr=err,
        fmt='none',
        ecolor='tab:blue',
        elinewidth=2.5,
        capsize=5,
        alpha=0.6   # 只影响误差条
    )


# 添加数值标签
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width + std[i]/2 + 2, bar.get_y() + bar.get_height()/2, f'{width}', ha='left', va='center',
             )
plt.xlim(45, 70)
# 设置标题和标签
plt.title('SEEDV 5-class Accuracy on different pretrain datasets')
plt.xlabel('ACC')
plt.ylabel('Pretrain Datasets')

# 显示图表
plt.grid(axis='x', linestyle='--', alpha=0.7)  # 添加横向网格线
plt.tight_layout()  # 调整布局
plt.show()
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
import matplotlib.pyplot as plt

# 数据
x = [1, 2, 3, 4, 5, 6, 7]
y = [72.78, 73.88, 73.96, 73.36, 74.15, 73.14, 72.87]
yerr = [3.41, 3.14, 3.86, 2.80, 3.24, 4.67, 3.42]  # 每个点的误差值

# 画带误差条的折线图
plt.errorbar(x, y, yerr=yerr, fmt='-o', color='blue', ecolor='red', capsize=5, label='Measured values')

# 添加标题和标签
plt.title('CDA effect on SEEDV dataset')
plt.xlabel('CDA factor')
plt.ylabel('Accuracy')

# 添加图例
plt.legend()

# 显示图表
plt.show()

# %%
import random

def random_sampling(n, k, m):
    if k > n:
        raise ValueError("k cannot be greater than n when sampling without replacement.")
    
    results = []
    for _ in range(m):
        sample = random.sample(range(n), k)
        results.append(sample)
    
    return results
random_sampling(50, 50//4, 6)
# Out:
# [[42, 41, 12, 15, 30, 13, 7, 10, 45, 4, 28, 20],
#  [10, 26, 37, 18, 34, 7, 22, 31, 35, 30, 47, 21],
#  [45, 37, 46, 40, 49, 14, 20, 11, 29, 42, 27, 2],
#  [24, 2, 23, 42, 25, 33, 15, 37, 6, 49, 30, 20],
#  [49, 29, 28, 20, 48, 15, 17, 8, 5, 39, 10, 0],
#  [25, 3, 7, 26, 48, 1, 31, 5, 33, 34, 36, 42]]

# %%
random_sampling(32, 32//4, 6)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.rcParams['font.family'] = 'Arial'

# 示例数据
datasets = ['F', 'S7', 'S3', 'S3+S7', 'S3+F', 'S3+S7+F', 'S3+S7+F+D', 'S3+S4+S7+F+D']

acc_dict = {
    'S7': 55.46,
    'F': 48.90,
    'S3': 56.47,
    'S3+S7': 59.46,
    'F+D': 0.0,
    'S3+F': 59.71,
    'S3+S7+F': 62.25,
    'S3+F+D': 61.93,
    'S3+S4+S7+D': 64.16,
    'S3+S7+F+D': 64.83,
    'S3+S4+S7+F+D': 65.02,
}
std_dict = {
    'S7': 2.49,
    'F': 1.91,
    'S3': 1.65,
    'S3+S7': 1.24,
    'F+D': 0.0,
    'S3+F': 1.90,
    'S3+S7+F': 1.22,
    'S3+F+D': 1.75,
    'S3+S4+S7+D': 1.70,
    'S3+S7+F+D': 1.52,
    'S3+S4+S7+F+D': 1.32
}


acc = [acc_dict[dataset_i] for dataset_i in datasets]
std = [std_dict[dataset_i] for dataset_i in datasets]

colormap = cm.get_cmap('Blues', 5)  # 将组合数量分为 5 个等级：1, 2, 3, 4, 5+

def dataset_color(dataset_name):
    count = dataset_name.count('+') + 1  # 计算组合数量
    count = min(count, 5)  # 限制最大为5，防止越界
    normalized = (count - 1) / 4  # 将1~5映射到0~1
    return colormap(normalized)  # 返回RGBA颜色

def dataset_color(dataset_name):
    count = dataset_name.count('+') + 1  # 计算组合数
    if count == 1:
        return '#93beec'
    elif count == 2:
        return '#6fa9e6'
    elif count == 3:
        return '#4c94e0'
    elif count == 4:
        return '#3c76b3'
    else:
        return '#2d5886'

colors = [dataset_color(name) for name in datasets]

# 创建横向柱状图
plt.figure(figsize=(8, 5))
bars = plt.barh(datasets, acc, color=colors)

# 添加误差条
for bar, err in zip(bars, std):
    x = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.errorbar(
        x, y,
        xerr=err,
        fmt='none',
        ecolor='gray',
        elinewidth=2.5,
        capsize=5,
        alpha=0.6
    )

# 添加数值标签
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width + std[i]/2 + 2, bar.get_y() + bar.get_height()/2,
             f'{width:.2f}', ha='left', va='center',
             fontsize=13)

plt.xlim(45, 70)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# plt.title('SEEDV 5-class Accuracy on Different Pretrain Datasets')
# plt.xlabel('ACC')
# plt.ylabel('Pretrain Datasets')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_867807/3601066041.py:39: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colormap = cm.get_cmap('Blues', 5)  # 将组合数量分为 5 个等级：1, 2, 3, 4, 5+
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...
